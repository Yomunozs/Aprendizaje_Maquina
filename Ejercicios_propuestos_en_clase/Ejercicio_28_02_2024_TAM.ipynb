# %% [markdown]
# <a href="https://colab.research.google.com/github/Yomunozs/Aprendizaje_Maquina/blob/main/Ejercicios_propuestos_en_clase/Ejercicio_28_02_2024_TAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 200
A = 8
f = 1/N
sigma = 4
mu = 3
dn = np.arange(0,N,1)
Xn = A * np.sin(2 * np.pi * f * dn)

#n = (1/(np.sqrt(2*np.pi*sigma)))*np.exp(-((Xn-mu)**2)/2*(sigma**2)) # Calcula una probabilidad
n = np.random.normal(mu, sigma, N) # Apartir de la probabilidad anterior
y = Xn *  n

# %%
plt.scatter(Xn, y)
plt.plot(Xn,n)

# %%
X = np.arange(0,N,1)
Y =  A * np.sin (2*np.pi*f*X) + n

# %%
plt.plot(X, Y)

# %%
def poliph(x):
  phi = []
  for i in range (N):
    #print(x[i])
    phi.append( x[i]**(i+1))
    #print(phi[i])
  return phi

# %%
Xp = poliph(X)
Xp
# Out:
# [0,
#  1,
#  8,
#  81,
#  1024,
#  15625,
#  279936,
#  5764801,
#  134217728,
#  3486784401,
#  100000000000,
#  3138428376721,
#  106993205379072,
#  3937376385699289,
#  155568095557812224,
#  6568408355712890625,
#  0,
#  6665467901046659617,
#  -8946610666848387072,
#  -8405864196579009711,
#  -5135277853620830208,
#  3378936079663493801,
#  -1081895540213415936,
#  -8560217158519514431,
#  0,
#  -3394226340030730831,
#  7687483363732488192,
#  5054814671472437393,
#  -7205759403792793600,
#  -5669414982636626567,
#  3192788766263607296,
#  3671467063254694913,
#  0,
#  -4627581747180550079,
#  4403158724777082880,
#  -895035433009375151,
#  0,
#  -7485270217780920247,
#  8847318719190269952,
#  7457877219813651649,
#  0,
#  569720415935503313,
#  7080898863342551040,
#  -9044013308894903151,
#  0,
#  6544475813497720089,
#  5121577938738741248,
#  6949785565411188481,
#  0,
#  3728452490685454945,
#  -267964177828544512,
#  -3586109361776883887,
#  0,
#  -3580196054852733463,
# ...

# %%
def gausph(x):
# Out:
#   File "<ipython-input-14-b4441e886d68>", line 1
#     def gausph(x):
#                   ^
# SyntaxError: incomplete input
